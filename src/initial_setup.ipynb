# %% [markdown]
# ## Initial Setup - Create Schema and Volume

# %%
# %sql
CREATE CATALOG IF NOT EXISTS etl;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS etl.raw;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS etl.raw.nyc_taxi

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS etl.bronze;
